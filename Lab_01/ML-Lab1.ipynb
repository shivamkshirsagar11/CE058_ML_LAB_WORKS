# %%
import numpy as np
arr = np.array([[1,2],[5,6]])
arr3 = np.array([[10,12],[5,6]])
arr1 = [[1,2,4,5,6],[1,2,4,5,6]]
arr2 = [[6,7,8,9,10],[6,7,8,9,10]]
# print(arr,arr2,arr+arr2)
# print(arr[0],arr[-1],arr[2:],arr[1:3])
# print(arr2*arr1)
# print(arr*arr3)
# print(np.multiply(arr,arr3)) just multiply element 1-1
# print(np.dot(arr,arr3)) it is like m.m.
# print(np.add(arr2,arr1))
#  for any operation on both marix, they has to be same dimention or for dot rules of m.m.
#  we can use @ for dot product 
#  add,substract, multiply, divide, dot - @ functions
# x = np.array([[1,2],[3,4]])
# print(x.sum(axis = 1),x.sum(axis = 0))
#  axis 0 means column, axis 1 means row
# x = np.array([1,2])
# print(x.sum(axis = 0),x.sum(axis = 1))
#  error on sum axis 1 when only 1 dimention array
# print(x.T) for transpose
# matrix = np.array([[1,2],[3,4],[5,6]],dtype=object)
# matrix = np.array([[1,2],[3,4],[5,6,7]],dtype=object)
# print(matrix * 2)
#  if badmatrix formed then some operation will malfunction like * 2 will scale matrix based on element
#  on good matrix it'll be like as scaling each element's value
# other function of matrix will be same as np.array functions like add,multiply,substract etc...
# ------------------------------------------------------------------------------------------------------------------
# nparray1 = np.array([1, 2, 3, 4]) # Define an array
# norm1 = np.linalg.norm(nparray1)
# nparray2 = np.array([[1, 2], [3, 4]])
# norm2 = np.linalg.norm(nparray2)
# print(norm1)
# print(norm2)
# print(np.linalg.norm(nparray2,axis = 1),np.linalg.norm(nparray2,axis=0))
#  dot is same np.dot or anynparray.sum(arr1*arr2) or anynparray.dot(othernparray)
# sum by row and column we know using sum(axis = 0 or 1)
# -------------------------------------------------------------------------------------------------------------------
#  exploiting mean by row, column and whole matrix
# x = np.array([[1,2],[3,4]])
# print(x.mean())
# print(x.mean(axis=0,dtype=np.int32))
# print(x.mean(axis=0))
# print(x.mean(axis=1))
# -------------------------------------------------------------------------------------------------------------------
#  centering matrix by column 
# x = np.array([[1,1],[2,2],[3,3]])
# centered = x - x.mean(axis = 0) #get mean of columns and then reduce it for every row that way we will get centered column matrix
# print(centered)
# print(centered.sum(axis = 1))
# print(centered.sum(axis = 0))
# print(centered.mean(axis = 1))
# print(centered.mean(axis = 0))

# %% [markdown]
# **NLTK** library</br>
# ---
# **for pre processing...**
# 1.   Lowercasing
# 2.   Tokenization
# 3.   Remobing stop words
# 4.   Stemming

# %%
import nltk
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# True
